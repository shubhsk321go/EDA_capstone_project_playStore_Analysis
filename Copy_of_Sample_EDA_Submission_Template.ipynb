# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhsk321go/EDA_capstone_project_playStore_Analysis/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
# # EDA Play Store App Review Analysis

# %% [markdown]
# ![google-play.gif](data:image/gif;base64,...)

# %% [markdown]
# #### **Project Type**    - EDA
# #### **Contribution**    - Team
# #### **Team name - data_diggers**
# #### **Team Member 1 -Sabitendu Mahapatra**
# #### **Team Member 2 -Chaitanya Kenzi**
# #### **Team Member 3 -Himanshu Rathod**
# #### **Team Member 4 -Monika H S**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Hello, the author of this project is Shubham Kumar.
# I want to offer a quick overview of this project. In order to better understand the data's hidden insights and to extract useful information for the business and the team, I want to conduct exploratory data analysis (EDA) on the dataset using user data from Playstore apps. I also want to review the data and find any patterns, relationships, or trends that have been discovered.
#
# Basically, the process consists of five steps: capture, maintenance, processing, analysis, and communication. Playstore is a platform that allows users to access various programmes on their mobile devices and utilise them in accordance with their needs or preferences. These apps are produced by various businesses, occasionally by individuals, and occasionally by institutions.
# Every day, dozens of new mobile applications are uploaded to systems for app distribution like Google Play, and thousands more developers work alone or collaboratively to make them popular. A developer must ascertain whether he is moving in the proper way due to the fierce competition from all around the world. The number of installations and user reviews an app receives over the course of its existence, rather than the amount of money it makes, often determines how successful it is.We used exploratory data analysis to uncover connections between particular features, such as how the number of words in an app's name affects installs, in order to use these relationships to identify which apps will have the best chances of succeeding.
#
# To provide them the best possible result of our investigation, we concentrated on data preparation and cleansing in the first stage. Data cleansing was a big problem for us. We have taken a few measures in data cleaning to assure the accuracy of the data, such as deleting null values. 13.60% of the ratings were determined to be null values during the data cleaning process, and even after combining the two data frames, we were unable to make many inferences to fill them. So, we had to abandon them.
#
# We could have used the 42% of null values in the User Reviews to better grasp the attitudes within each category, which would have filled 15.60% of the null values in the Rating column.
# There were only 816 common applications in the Play Store and user evaluations' combined data set. This only represents 10% of the cleaned data; if the remaining 70%–80% had been accessible in the combined data frames, we might have provided a more insightful analysis.
#
# We have conducted exploratory data analysis with the cleaned data to better understand our dataset, such as the quantity of installations for each category. We looked at the frequency distributions of categorical data as well as the distribution of all numerical data. We also discovered the relationships between other pieces of information, such as category and install, rating and review, sentiment subjectivity and sentiment polarity, rating, and so on.
#
# We came to the conclusion that people prefer more free apps after doing the analysis. Since most of the apps in the Play Store are about the same size, size doesn't really factor into their choices. The vast majority of the dataset's apps are compact in size. The majority of the apps on the Google Play Store were discovered to have ratings between 4 and 5. Everyone is the app's predominate content rating, and the most common genre is conversation.
#
# Based on the quantity of installs as well as the quantity of reviews, we identified the most well-liked applications. With this reasoning, Facebook is the most widely used app, and WhatsApp has now followed.
#
# Positive ratings predominate, with a smaller number of reviews for neutral and unfavourable opinions. The majority of the evaluations lie within [-0.50, 0.75] on the polarity scale, suggesting that neither exceptionally favourable nor negative opinions are prevalent.
# The majority of the evaluations exhibit a spectrum of opinions, both favourable and unfavourable. Although sentiment subjectivity is not always inversely correlated with sentiment polarity, it typically exhibits linear behaviour when variance is either too high or too low.
#
# The problem's reach extends beyond what is being taken into account for this project. We may infer that we have achieved the group project's goal of app analysis based on the outcomes and procedures we have used and check the trends of the GPS(Google Play Store).

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/shubhsk321go/EDA_capstone_project_playStore_Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# One of the most well-known app stores in the world, Google Play Store is used by millions of people. The need for developers is rising along with the app store business. Users may download a variety of apps from the Play Store based on their interests, and they also have the option to rank and review the apps based on their personal usage experiences.
#
# The size, pricing, Android version, when the app was last updated, and other elements should be considered in the development of a successful and interesting app.
#
# Before creating the applications, developers should be aware of how existing apps with features comparable to the planned app are received by users.
# For the investigation of user preference and sentiment, two datasets are offered: one contains fundamental app-related data, and the other contains user reviews and attitudes for specific apps. It is necessary to look at both datasets in order to pinpoint the key elements that affect app success and engagement.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Play Store's app data offers a great deal of potential to help app development companies succeed. The primary goals are for this to have more installs, a high rating, and more favourable reviews. In order to attain the desired success and engagement, we must investigate and analyse the datasets.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import missingno as msno
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset First Look
ps_data_path='/content/drive/MyDrive/alma better/EDA/Play Store Data.csv'
df_ps=pd.read_csv(ps_data_path)

# %% [markdown]
# ### Dataset First View

# %%
#let's watch the first 10 row
df_ps.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
#let's look to the last 10 rows
df_ps.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 10831       Everyone  Maps & Navigation       June 13, 2018
# 10832       Everyone            Weather   February 16, 2014
# 10833       Everyone  Books & Reference      March 23, 2014
# 10834       Everyone          Education       June 18, 2017
# 10835       Everyone           Business  September 29, 2016
# 10836       Everyone          Education       July 25, 2017
# 10837       Everyone          Education        July 6, 2018
# 10838       Everyone            Medical    January 20, 2017
# 10839     Mature 17+  Books & Reference    January 19, 2015
# 10840       Everyone          Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df_ps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#find no of rows and columns in the dataset
rows=df_ps.shape[0]
column=df_ps.shape[1]
print(f"no of rows is {rows} and no of columns is {column}")
# Out:
# no of rows is 10841 and no of columns is 13

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df_ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
#  **From above, we can observe two major facts, and they are**
#
#
# 1.   **Out of 13 columns, 1 is numerical, the rest are categorical values.**
#
# 2.   **There are a few nulls present in the dataset; we will inspect them.**

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate=df_ps[df_ps.duplicated(subset='App')]
duplicate.head(4)
# Out:
#                               App  Category  Rating Reviews  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 236                           Box  BUSINESS     4.2  159872
# 239            Google My Business  BUSINESS     4.4   70991
# 256           ZOOM Cloud Meetings  BUSINESS     4.4   31614
#
#                    Size     Installs  Type Price Content Rating    Genres  \
# 229  Varies with device   5,000,000+  Free     0       Everyone  Business
# 236  Varies with device  10,000,000+  Free     0       Everyone  Business
# 239  Varies with device   5,000,000+  Free     0       Everyone  Business
# 256                 37M  10,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver         Android Ver
# 229  February 26, 2018  Varies with device        4.0.3 and up
# 236      July 31, 2018  Varies with device  Varies with device
# 239      July 24, 2018    2.19.0.204537701          4.4 and up
# 256      July 20, 2018      4.1.28165.0716          4.0 and up

# %%
#find the count of the duplicate data in the dataset
rows_duplicate=duplicate.shape[0]
print(f"no of duplicate data is {rows_duplicate} is the dataset")
# Out:
# no of duplicate data is 1181 is the dataset

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df_ps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# It's look like only 5 columns has  missing data
#
# **1.Rating column**
#
# **2.Current Version**
#
# **3.Android Version**
#
# **4.Type**
#
# **5.Content Rating**

# %%
# Visualizing the missing values
msno.matrix(df_ps)
# Out:
# <Axes: >

# %% [markdown]
# According to the matrix plot shown above, the missing values for the Rating column are dispersed across the matrix, the missing value for the current_ver column is close to the end of the column, and depending on the quantity of data, the missing values for other columns are not viewable.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# On the basis of our assessment, let's first describe the information the columns hold.
#
# play_store 13 columns and 10841 rows make up the dataframe. The following list identifies the 13 columns:
#
#
#
# * **App** - It provides information about the application's name.
# * **Category** - It assigns the app a category, such as instructional, sporting, or gaming.
#
# * **Rating** - This section includes the overall user rating that the corresponding app has gotten.
# * **Reviews** - This information provides information on the total number of people who have evaluated the application.
#
# * **Size** - It provides information on the amount of space the mobile application takes up on the device.
#
# * **Installs** - This information reveals how many times the application has been downloaded and installed overall.
# * **Type** - Indicates whether an app is a paid or free download.
#
# * **Price** - This indicates the cost to install the application. The cost is 0 for apps of the free variety.
#
# * **Content Rating** - Indicates whether or not an app is appropriate for users of all ages.
#
# * **Genres** - It informs us of the several additional groups to which an application may belong.
# * **Last Updated** - It provides information about the most recent update to the application.
#
# * **Current Version**  It provides information on the application's most recent version.
#
# * **Android version** It provides information about the Android version that can run the application.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# In this dataset, the primary column is app, as it states
#
# 1.   List item
# 2.   List item
#
# the particular app name that should be unique in the dataset.

# %%
# Dataset Columns
df_ps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe (view the basic statistical details)
df_ps.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# Only the rating column is numerical; the others contain categorical data.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Only the rating column contains numbers; all other columns include category information.The maximum rating column, as seen below, is 19. Given a rating of 5, this is unacceptable. As a result, the data is flawed.The lowest rating offered is 1.0.We are unable to draw any statistical conclusions due to the dataset's damaged data.

# %%
#let's look at the number of corrupted data in the Rating column
df_ps[(df_ps['Rating']>5.0) | (df_ps['Rating']<1.0)]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# In the Rating column, there is only one corrupted value, and for the same app, there is also a null value for Content Rating. We can drop this row.

# %%
#drop the row
df_ps.drop(index=10472,inplace=True)
df_ps.shape
# Out:
# (10840, 13)

# %%
#statiscal description of the numerical column
df_ps.describe()
# Out:
#             Rating
# count  9366.000000
# mean      4.191757
# std       0.515219
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %% [markdown]
# The maximum rating is between 4.0 and 4.5, and the average rating is around 4.2.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df_ps.nunique()
# Out:
# App               9659
# Category            33
# Rating              39
# Reviews           6001
# Size               461
# Installs            21
# Type                 2
# Price               92
# Content Rating       6
# Genres             119
# Last Updated      1377
# Current Ver       2831
# Android Ver         33
# dtype: int64

# %% [markdown]
# In this dataset
#
# *   **There are 9659 apps are present,it is the primary key of this dataset**
# *   **There are 33 categories in the dataset,i.e-games,family,medical**
# *   **2 types are free and paid**
# *   **6 type of content rating**
# *   **118 different genres**
# *   **33 diffrent android version**

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ## 3.1 Drop the Duplicate value

# %% [markdown]
# ### Data Wrangling Code

# %%
#drop the duplicate values based on app column
df_ps.drop_duplicates(subset='App',keep='first',inplace=True)
#check the no of rows in the dataset after dropping the dataset
df_ps.shape
# Out:
# (9659, 13)

# %% [markdown]
# ## 3.2 Dealing with the missing value

# %%
#let's understand the missing with more detailis.Here we gonna create a function which will tells us in detalis about missing data
def missingdata_info(df):
  '''
  This function is helps to find the missing data in details
  '''
  missing_df=pd.DataFrame(index=df.columns)
  missing_df['datatypes']=df.dtypes
  missing_df['total no of value']=[len(df)]*len(missing_df)
  missing_df['not null value']=df.count()
  missing_df['null values']=df.isna().sum()
  missing_df['percentage  of null value']=(missing_df['null values']/len(df))*100
  ms_df=missing_df[missing_df['null values']>0]
  return ms_df

# %%
#apply the funtion to dataframe for understand the missing value
missingdata_info(df_ps)
# Out:
#             datatypes  total no of value  not null value  null values  \
# Rating        float64               9659            8196         1463
# Type           object               9659            9658            1
# Current Ver    object               9659            9651            8
# Android Ver    object               9659            9657            2
#
#              percentage  of null value
# Rating                       15.146495
# Type                          0.010353
# Current Ver                   0.082824
# Android Ver                   0.020706

# %% [markdown]
# *   **Nearly 15 percent of the data in the rating columns is missing, and it is near about 1463 columns.**
#
#
# *  **Rests of the missing column type,content rating current version android version is fewer missing columns and it is less than 1 percent**

# %% [markdown]
# ##3.2.1 Dealing with Android Ver column

# %%
#check out the android ver missing rows
df_ps[df_ps['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
#finding the number of different value in Android Ver
df_ps['Android Ver'].value_counts()
# Out:
# 4.1 and up            2202
# 4.0.3 and up          1395
# 4.0 and up            1285
# Varies with device     990
# 4.4 and up             818
# 2.3 and up             616
# 5.0 and up             512
# 4.2 and up             372
# 2.3.3 and up           273
# 2.2 and up             239
# 3.0 and up             231
# 4.3 and up             221
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              54
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %% [markdown]
# As we can see, the Nan value of the Android version is difficult to alter since it contains a large number of unique values and is widely distributed among them. We may disregard that because there are only 3 rows and it amounts to less than 0.02 percent.

# %%
#drop the null value of the Android Ver column
df_ps=df_ps[df_ps['Android Ver'].notnull()]
#check the shape of the dataframe after dropping missing Android ver column
df_ps.shape
# Out:
# (9657, 13)

# %% [markdown]
# ##3.2.2 Dealing with Current Ver column

# %%
#check out the current ver missing rows
df_ps[df_ps['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# 6322   8.7M    500,000+  Free      0       Everyone              Tools
# 6803   222k        100+  Free      0       Everyone          Education
# 7333    14M     50,000+  Paid  $0.99       Everyone             Puzzle
# 7407   7.2M     10,000+  Free      0       Everyone      Entertainment
# 7730   237k         10+  Paid  $0.99       Everyone              Tools
# 10342  658k      1,000+  Free      0       Everyone  Books & Reference
#
#             Last Updated Current Ver Android Ver
# 15          June 6, 2018         NaN  4.2 and up
# 1553   February 12, 2013         NaN  1.5 and up
# 6322        May 10, 2017         NaN  4.0 and up
# 6803    November 6, 2016         NaN  1.6 and up
# 7333      April 18, 2018         NaN  4.0 and up
# 7407       April 3, 2017         NaN  2.3 and up
# 7730        July 4, 2016         NaN  2.0 and up
# 10342   January 31, 2017         NaN  3.0 and up

# %%
#finding the number of different value in Current Ver
df_ps['Current Ver'].value_counts()
# Out:
# Varies with device    1055
# 1.0                    799
# 1.1                    259
# 1.2                    176
# 2.0                    149
#                       ...
# 2.27.1                   1
# 1.6.11                   1
# 20180517                 1
# 3.1.00                   1
# 2.0.148.0                1
# Name: Current Ver, Length: 2817, dtype: int64

# %% [markdown]
# We can see that the Nan value of the current version is difficult to alter since it is spread out among a large number of unique values in the current version. We may remove it because there are only 8 rows and the Nan value is just 0.08 percent.

# %%
#Dropping the missing current ver data
df_ps=df_ps[df_ps['Current Ver'].notnull()]
#check out the shape of the dataframe  after dropping current ver missing data
df_ps.shape
# Out:
# (9649, 13)

# %% [markdown]
# ##3.2.3 Dealing with type column

# %%
#finding the null value in Type column
df_ps[df_ps['Type'].isnull()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
#find the type column data  spread
df_ps['Type'].value_counts()
# Out:
# Free    8895
# Paid     753
# Name: Type, dtype: int64

# %% [markdown]
# ### **The dataset has just two distinct categories. If type were free, there would be no cost, and if type were a paid service, there would be a cost. Therefore, we may substitute "free" for the type.**

# %%
#replace the Nan value of type column with free
df_ps['Type'].fillna('Free',inplace=True)

# %% [markdown]
# ##3.2.4 Dealing with the Rating column

# %%
#find out the missing rating data or rating is 0 in the dataset
df_ps[(df_ps['Rating'].isnull()) | (df_ps['Rating']==0)]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# 23         61  7.0M  100,000+  Free     0       Everyone
# 113       182  5.7M  100,000+  Free     0   Everyone 10+
# 123       119  3.7M   50,000+  Free     0       Everyone
# 126       654  7.4M  100,000+  Free     0           Teen
# 129        77  2.9M   10,000+  Free     0     Mature 17+
# ...       ...   ...       ...   ...   ...            ...
# 10824      67   82M   10,000+  Free     0       Everyone
# 10825       7  7.7M      100+  Free     0           Teen
# 10831      38  9.8M    5,000+  Free     0       Everyone
# 10835       0  9.6M       10+  Free     0       Everyone
# 10838       3  9.5M    1,000+  Free     0       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                             Beauty  September 20, 2017         8.0
# 123                             Beauty       July 23, 2018         1.3
# 126                             Beauty       July 17, 2018        1.15
# 129                             Beauty      August 8, 2017         2.0
# ...                                ...                 ...         ...
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                         Business  September 29, 2016       1.1.5
# 10838                          Medical    January 20, 2017         1.0
#
#       Android Ver
# 23     4.1 and up
# 113    3.0 and up
# 123    4.1 and up
# 126    4.1 and up
# 129    2.3 and up
# ...           ...
# 10824  4.4 and up
# 10825  4.0 and up
# 10831  4.0 and up
# 10835  4.0 and up
# 10838  2.2 and up
#
# [1459 rows x 13 columns]

# %%
#find out the rating rows whose value is more than 5
df_ps[(df_ps['Rating']>5)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **The dataset has a large number of null values. We must replace this data since we cannot discard it. The rating's data type is numerical. We must keep an eye on how the data are distributed in this column.**

# %%
#try to understand the distribution of the data with histplot and boxplot
fig, ax = plt.subplots(2,1, figsize=(15,8))
plt.grid()
sns.histplot(df_ps['Rating'], color ='red', bins = 10,kde=True,ax=ax[0])
sns.boxplot(x=df_ps['Rating'],data=df_ps,ax=ax[1])
# Out:
# <Axes: xlabel='Rating'>

# %% [markdown]
# **From the above figure, we can see that the distribution is negatively skewed. So replacing the null value with the mean value may be inappropriate because an outlier is present on the left side of the data.**

# %%
#find the mean,median and mode value of the rating column
mean_value=round(df_ps[~df_ps['Rating'].isnull()].Rating.mean(),1)
median_value=df_ps[~df_ps['Rating'].isnull()].Rating.median()
mode_value=df_ps['Rating'].mode()
print(f"The mean value is {mean_value}, median value is {median_value} and mode value is {mode_value}")
# Out:
# The mean value is 4.2, median value is 4.3 and mode value is 0    4.3
# Name: Rating, dtype: float64

# %% [markdown]
# The median value and mode value are the same,so we will replace the null values
#
# *   List item
# *   List item
#
# with the median value.

# %%
#replace the Nan value of Rating column with median value
df_ps['Rating'].fillna(median_value,inplace=True)

# %%
#check once again if there is any null value
df_ps.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ##3.3 Reshaping the data

# %% [markdown]
# **For the data analysis Reviews, sizes, prices,installs should be in numeric values. So these columns need to be converted into numeric values. The Last Updated column should be in datetime format.**

# %% [markdown]
# ### 3.3.1 Change the datatype of Review column

# %%
#changing the review datatype from object to integer
df_ps['Reviews']=df_ps['Reviews'].astype(int)
#check the datatype of the column after change
df_ps['Reviews'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### 3.3.2 Change the datatype of Size column

# %%
#look at the format of the data of size column
df_ps['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M',
#        '11M', '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M',
#        '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M',
#        '5.7M', '8.6M', '2.4M', '27M', '2.7M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '80M', '1.7M', '74M',
#        '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M', '71M',
#        '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k', '899k',
#        '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M', '89M',
#        '696k', '544k', '525k', '920k', '779k', '853k', '720k', '713k',
#        '772k', '318k', '58k', '241k', '196k', '857k', '51k', '953k',
#        '865k', '251k', '930k', '540k', '313k', '746k', '203k', '26k',
#        '314k', '239k', '371k', '220k', '730k', '756k', '91k', '293k',
#        '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k', '81k',
#        '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '219k', '55k', '948k', '323k', '691k',
#        '511k', '951k', '963k', '25k', '554k', '351k', '27k', '82k',
#        '208k', '913k', '514k', '551k', '29k', '103k', '898k', '743k',
#        '116k', '153k', '209k', '353k', '499k', '173k', '597k', '809k',
#        '122k', '411k', '400k', '801k', '787k', '50k', '643k', '986k',
#        '97k', '516k', '837k', '780k', '961k', '269k', '20k', '498k',
#        '600k', '749k', '642k', '881k', '72k', '656k', '601k', '221k',
#        '228k', '108k', '940k', '176k', '33k', '663k', '34k', '942k',
#        '259k', '164k', '458k', '245k', '629k', '28k', '288k', '775k',
#        '785k', '636k', '916k', '994k', '309k', '485k', '914k', '903k',
#        '608k', '500k', '54k', '562k', '847k', '957k', '688k', '811k',
#        '270k', '48k', '329k', '523k', '921k', '874k', '981k', '784k',
#        '280k', '24k', '518k', '754k', '892k', '154k', '860k', '364k',
#        '387k', '626k', '161k', '879k', '39k', '970k', '170k', '141k',
#        '160k', '144k', '143k', '190k', '376k', '193k', '246k', '73k',
#        '992k', '253k', '420k', '404k', '470k', '226k', '240k', '89k',
#        '234k', '257k', '861k', '467k', '157k', '44k', '676k', '67k',
#        '552k', '885k', '1020k', '582k', '619k'], dtype=object)

# %% [markdown]
# **Here M denotes the size in MB (MegaByte) and k denotes kB (kiloByte). Before converting the data, the unit of the size should be unique, and 'k' and 'M' should be omitted.**

# %%
# create a function to convert the data into numerical and unit of MB
def size_convert(app_size):
  '''
  This is the function to convert the size into kb to mb
  '''
  try:
    if app_size[-1]=='M':
      return float(app_size[:-1])
    elif app_size[-1]=='k':
      return round((float(app_size[:-1])/1024),2)
    else:
      return float(app_size)
  except:
    return app_size

# %%
#convert the column as suggested
df_ps['Size']=df_ps['Size'].apply(lambda size:size_convert(size))
#check the datatype of the column after applying function on the column
df_ps['Size'].dtype
# Out:
# dtype('O')

# %% [markdown]
# **datatype is still an object type because 'varies with device' size is present in the dataset. So it can't convert the entire column to numbers.**

# %% [markdown]
# ## 3.3.3 Dealing with Installs columns

# %%
#look at the format of the column
df_ps['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %% [markdown]
# **In the Install column, there are '+' and ',' which need to be filtered before being converted to numeric.**

# %%
#create a function to convert install coumn to numeric data
def install_to_numeric(column_data):
  '''
  This function is omit the + and , in the data and turn into numeric
  '''
  if '+'and ',' in column_data:
    data=int(column_data[:-1].replace(',',''))
    return data
  elif '+' in column_data:
    data=int(column_data[:-1])
    return data
  elif ',' in column_data:
    data=int(column_data.replace(',',''))
    return data
  else:
    return int(column_data)

# %%
#apply the function to convert install data into numeric
df_ps['Installs']=df_ps['Installs'].apply(lambda x:install_to_numeric(x))
df_ps.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0     10000  Free     0       Everyone
# 1      967  14.0    500000  Free     0       Everyone
# 2    87510   8.7   5000000  Free     0       Everyone
# 3   215644  25.0  50000000  Free     0           Teen
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up

# %% [markdown]
# ##3.3.4 Dealing the Price Column
# The price column must be converted to numeric data. There is a "$' in the price data. We need to eliminate it.

# %%
def price_to_numeric(price):
  '''
  This function is to convert price column datatype into numeric
  '''
  if '$' in price:
    new_price=float(price.replace('$',''))
    return new_price
  else:
    return float(price)

# %%
# apply the function into  price column
df_ps['Price']=df_ps['Price'].apply(lambda x:price_to_numeric(x))
#check the price column of the data which have non zero price
df_ps[df_ps['Price']!=0].head(4)
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
# 476                      Moco+ - Chat, Meet People         DATING     4.2
#
#      Reviews                Size  Installs  Type  Price Content Rating  \
# 234    11442                 6.8    100000  Paid   4.99       Everyone
# 235    10295                39.0    100000  Paid   4.99       Everyone
# 427    18247  Varies with device    100000  Paid   3.99       Everyone
# 476     1545  Varies with device     10000  Paid   3.99     Mature 17+
#
#             Genres    Last Updated  Current Ver Android Ver
# 234       Business  March 25, 2018        1.5.2  4.0 and up
# 235       Business  April 11, 2017        3.4.6  3.0 and up
# 427  Communication    July 5, 2018  7.5.3.20547  4.1 and up
# 476         Dating   June 19, 2018      2.6.139  4.1 and up

# %% [markdown]
# ### 3.3.5 Dealing with Last Updated Column
#
#
#
#
# Last Updated column need to be convert into datetime format

# %%
# Pandas to_datetime() function applied to the values in the last updated column
df_ps['Last Updated']=pd.to_datetime(df_ps['Last Updated'])
#check the dataframe after converting to datetime
df_ps.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up

# %% [markdown]
# ## User Review Data load and Data preparation for Analysis

# %%
#load the user review dataset
ur_path='/content/drive/MyDrive/alma better/EDA/User Reviews.csv'
df_ur=pd.read_csv(ur_path)
df_ur.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#user review dataset information
df_ur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
#  There are only 5 colums
#
# *   **2 columns are numerical, and they are sentiment polarity and sentiment subjectivity.**
#
# *   **There are 3 columns with categorical values: app, translated review, and sentiment.**
# *   **There are lots of null values present in the dataset. We need to inspect the dataset on this.**

# %%
# view the basic statistical details
df_ur.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### User Review dataset information
# user_reviews dataframe has 64295 rows and 5 columns. The 5 columns are identified as follows:
#
# * **App:** Contains the name of the app with a short description (optional).
# * **Translated_Review:** It contains the English translation of the review dropped by the user of the app.
# * **Sentiment:** It gives the attitude/emotion of the writer. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
# * **Sentiment_Polarity:** It gives the polarity of the review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.
# * **Sentiment_Subjectivity:** This value gives how close a reviewers opinion is to the opinion of the general public. Its range is [0,1]. Higher the subjectivity, closer is the reviewers opinion to the opinion of the general public, and lower subjectivity indicates the review is more of a factual information.

# %%
#columns of the data set
print(df_ur.columns)
rows=df_ur.shape[0]
cols=df_ur.shape[1]
print(f"The user review data set has {rows} rows and {cols} columns")
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')
# The user review data set has 64295 rows and 5 columns

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
# Understand the missing data in details
missingdata_info(df_ur)
# Out:
#                        datatypes  total no of value  not null value  \
# Translated_Review         object              64295           37427
# Sentiment                 object              64295           37432
# Sentiment_Polarity       float64              64295           37432
# Sentiment_Subjectivity   float64              64295           37432
#
#                         null values  percentage  of null value
# Translated_Review             26868                  41.788631
# Sentiment                     26863                  41.780854
# Sentiment_Polarity            26863                  41.780854
# Sentiment_Subjectivity        26863                  41.780854

# %% [markdown]
# *   We can see that around 42 percent are missing value in all columns
# * **Translated_Review** has 26868 null values which contributes **41.79%** of the data.
# * **Sentiment** has 26863 null values which contributes **41.78%** of the data.
# * **Sentiment_Polarity**  has 26863 null values which contributes **41.78%** of the data.
# * **Sentiment_Subjectivity** has 26863 null values which contributes **41.78%** of the data.

# %%
#find out where all the column has null value
df_na=df_ur[df_ur['Translated_Review'].isna() & df_ur['Sentiment'].isna() & df_ur['Sentiment_Polarity'].isna() & df_ur['Sentiment_Subjectivity'].isna()]
df_na.head()
# Out:
#                        App Translated_Review Sentiment  Sentiment_Polarity  \
# 2    10 Best Foods for You               NaN       NaN                 NaN
# 7    10 Best Foods for You               NaN       NaN                 NaN
# 15   10 Best Foods for You               NaN       NaN                 NaN
# 102  10 Best Foods for You               NaN       NaN                 NaN
# 107  10 Best Foods for You               NaN       NaN                 NaN
#
#      Sentiment_Subjectivity
# 2                       NaN
# 7                       NaN
# 15                      NaN
# 102                     NaN
# 107                     NaN

# %%
#check the length of the dataframe
print(len(df_na))
# Out:
# 26863

# %% [markdown]
# *   26863 rows have all null valus.
# *   This rows need to be dropped

# %%
#copy the na dataframe
df_na_1=df_na.copy()
#drop the rows which have all null value using isin function
df_ur.drop(df_na_1.index, axis=0,inplace=True)
#check the dataframe shape after drop
df_ur.shape
# Out:
# (37432, 5)

# %%
#check if any null vale in dataframe
df_ur.isna().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# Now only Translated Review has 5 null values

# %%
#check the rows which have null values of translated review
df_ur[df_ur['Translated_Review'].isna()]
# Out:
#                                              App Translated_Review Sentiment  \
# 268                                         11st               NaN   Neutral
# 15048        Birds Sounds Ringtones & Wallpapers               NaN   Neutral
# 22092             Calorie Counter - MyFitnessPal               NaN   Neutral
# 31623                                  DC Comics               NaN   Neutral
# 52500  Garden Photo Frames - Garden Photo Editor               NaN   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 268                   0.0                     0.0
# 15048                 0.0                     0.0
# 22092                 0.0                     0.0
# 31623                 0.0                     0.0
# 52500                 0.0                     0.0

# %%
#check the unique values of translated review
df_ur['Translated_Review'].unique()
# Out:
# array(['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#        'This help eating healthy exercise regular basis',
#        'Works great especially going grocery store', ...,
#        'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.',
#        'I property business got link SMS happy performance still guys need raise bar guys Cheers',
#        'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active'],
#       dtype=object)

# %% [markdown]
# Null values in the translated review can't be replaced. So we need to drop them.

# %%
#drop the null values
df_ur.dropna(inplace=True)
df_ur.shape
# Out:
# (37427, 5)

# %%
#check the last 5 rows of the dataframe after data cleaning
df_ur.tail()
# Out:
#                                   App  \
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000

# %% [markdown]
# ## Merge the two Dataframe

# %%
#create a groupby of app and sentiment and form a new dataframe
g_df=df_ur.groupby(['App','Sentiment']).size().unstack(level=1)
g_df.reset_index( inplace=True)
g_names=['App','Negative_Sentiment', 'Neutral_Sentiment','Positive_Sentiment']
g_df.columns=g_names
g_df.head()
# Out:
#                                 App  Negative_Sentiment  Neutral_Sentiment  \
# 0             10 Best Foods for You                10.0               22.0
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                 1.0                8.0
# 2                              11st                 7.0                9.0
# 3        1800 Contacts - Lens Store                 6.0               10.0
# 4   1LINE – One Line with One Touch                 8.0                3.0
#
#    Positive_Sentiment
# 0               162.0
# 1                31.0
# 2                23.0
# 3                64.0
# 4                27.0

# %%
#add mean sentiment polarity and and mean sentiment to the dataframe
app_list=list(df_ur['App'].unique())
sen_pol=[]
sen_sub=[]
for i in app_list:
  app_df=df_ur[df_ur['App']==i]
  sen_pol.append(app_df['Sentiment_Polarity'].mean())
  sen_sub.append(app_df['Sentiment_Subjectivity'].mean())
g_df['Mean_Sentiment_Polarity']=sen_pol
g_df['Mean_Sentiment_Subjectivity']=sen_sub
g_df.head()
# Out:
#                                 App  Negative_Sentiment  Neutral_Sentiment  \
# 0             10 Best Foods for You                10.0               22.0
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                 1.0                8.0
# 2                              11st                 7.0                9.0
# 3        1800 Contacts - Lens Store                 6.0               10.0
# 4   1LINE – One Line with One Touch                 8.0                3.0
#
#    Positive_Sentiment  Mean_Sentiment_Polarity  Mean_Sentiment_Subjectivity
# 0               162.0                 0.470733                     0.495455
# 1                31.0                 0.392405                     0.545516
# 2                23.0                 0.185943                     0.455340
# 3                64.0                 0.318145                     0.591098
# 4                27.0                 0.196290                     0.557315

# %%
#find any null value in new g_df
g_df.isna().sum()
# Out:
# App                              0
# Negative_Sentiment              83
# Neutral_Sentiment              124
# Positive_Sentiment              12
# Mean_Sentiment_Polarity          0
# Mean_Sentiment_Subjectivity      0
# dtype: int64

# %%
#fill the null value with zero
g_df.fillna(0,inplace=True)

# %%
#merge two dataframe by inner join
merged_df=pd.merge(df_ps,g_df,on='App',how='inner')
merged_df.head(4)
# Out:
#                                          App        Category  Rating  Reviews  \
# 0                        Coloring book moana  ART_AND_DESIGN     3.9      967
# 1                       Garden Coloring Book  ART_AND_DESIGN     4.4    13791
# 2              FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3   194216
# 3  Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1      654
#
#    Size  Installs  Type  Price Content Rating                     Genres  \
# 0  14.0    500000  Free    0.0       Everyone  Art & Design;Pretend Play
# 1  33.0   1000000  Free    0.0       Everyone               Art & Design
# 2  39.0   5000000  Free    0.0       Everyone               Art & Design
# 3  12.0    100000  Free    0.0       Everyone               Art & Design
#
#   Last Updated Current Ver   Android Ver  Negative_Sentiment  \
# 0   2018-01-15       2.0.0  4.0.3 and up                14.0
# 1   2017-09-20       2.9.2    3.0 and up                10.0
# 2   2018-08-03       2.2.5  4.0.3 and up                 0.0
# 3   2018-03-20         1.1  4.0.3 and up                 5.0
#
#    Neutral_Sentiment  Positive_Sentiment  Mean_Sentiment_Polarity  \
# 0                4.0                26.0                 0.152652
# 1               16.0                64.0                 0.268483
# 2                0.0                 4.0                 0.412649
# 3               10.0                23.0                 0.283509
#
#    Mean_Sentiment_Subjectivity
# 0                     0.641540
# 1                     0.523447
# 2                     0.679226
# 3                     0.479298

# %%
#find the shape of the merged dataframe
merged_df.shape
# Out:
# (816, 18)

# %% [markdown]
# Now we have total 3 dataframe for analysis

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *   **Dropped the null values of Type,Android ver and Current ver columns**
#
# *   **Replaced the null values of Rating column with median value**
#
#
# *  **Changed datatype of Review,Installs,Price to int value**
#
# *  **Changed the datatype of Size column to int except the varies with device**
#
# *   **Changed the datatype of Last Updated column to datetime format**
#
# *   **Dropped all null values of Translated_Review,Sentiment,Sentiment_Polarity,Sentiment_Subjectivity**
#
# *   **User review has lots of duplicate row in app column so before merge two dataframe user review data has been filterd according to app column and  formating other column to suit the dataframe**
#
# *   **The data pipeline has developed successfully. Now dataflow can be examined and visuals can be created. It is easy to compare different measures using the visualisations and thus draw implications from them.**

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ###**4.1 Univariate Analysis**
# Univariate analysis is the simplest form of analyzing data. “Uni” means “one”, so in other words our data has only one variable.It’s major purpose is to describe; It takes data, summarizes that data and finds patterns in the data.

# %% [markdown]
# ###4.1.1 **Analysis of Category column**

# %%
#Visualisation of No of app based on each category
fig,ax=plt.subplots(figsize=(18,10))
cat_app=df_ps['Category'].value_counts()
cat_app_vis=sns.barplot(x=cat_app.index,y=cat_app,palette="bright")
plt.xticks(rotation=60)
plt.xlabel('Category')
plt.ylabel('No of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The category column contains categorical data and has 33 unique values. Bar plots are used here to compare the frequency or count of the categorical data. So Bar Plot has chosen

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this plot, we can get the most and least popular categories of apps in the Play Store. We can see the Family category of the app has the highest number of apps, and it is above 1750. The beauty category has the lowest presence in the Play Store, and it is below 150.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This visualisation will help to understand the composition of each category of app. Family, Games, and Tools have the highest compettion, while parenting, comics, and beauty have the lowest.

# %% [markdown]
# ###4.1.2 **Analysis of Reviews and Installs Columns**

# %%
#statistics describe data of reviews and installs
df_ps[['Reviews','Installs']].describe()
# Out:
#             Reviews      Installs
# count  9.649000e+03  9.649000e+03
# mean   2.168145e+05  7.785404e+06
# std    1.832255e+06  5.378557e+07
# min    0.000000e+00  0.000000e+00
# 25%    2.500000e+01  1.000000e+03
# 50%    9.690000e+02  1.000000e+05
# 75%    2.944500e+04  1.000000e+06
# max    7.815831e+07  1.000000e+09

# %% [markdown]
# As Installs and Reviews columns are widely spread, it would be wise to put that on a logarithmic scale,but there is 0 in a few columns, so 1 will add to them to make them finite, and it would have about zero impact on analysis.

# %%
#visualisiation of Reviews and Installs distribution by histplot
df_ps['Reviews']=df_ps['Reviews'].apply(lambda x:x+1)
df_ps['Installs']=df_ps['Installs'].apply(lambda x:x+1)
#take the log value for high variance
Reviews=np.log10(df_ps['Reviews'])
Installs=np.log10(df_ps['Installs'])
fig,ax=plt.subplots(1,2,figsize=(15,6))
sns.boxplot(x=Reviews,data=df_ps,color='red',ax=ax[0])
sns.boxplot(x=Installs,data=df_ps,color='orange',ax=ax[1])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot uses boxes and lines to depict the distributions of one or more groups of numeric data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.    Most of apps has 250 to 30k reviews and 1000 to 1000000 no of installation
# 2.   Most of apps has  1000 to 1000000 no of installation
#
# 3.   Median value of Reviews are 969
#
# 4.   Median value of installation is 10000

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These data help to understand the relevance of the apps to customers. If the number of reviews for the app is above 30,000 and the number of installs is above 10,000,000, then the app is popular with users.

# %% [markdown]
# ###4.1.3 **Analysis of Type and Content Rating Column**

# %%
#pie chart visualisation of type and content rating
fig,ax=plt.subplots(1,2,figsize=(12,7))
ax[0].pie(x=df_ps['Type'].value_counts(),labels=df_ps['Type'].value_counts().index,explode=[0.2,0],autopct='%1.0f%%')
ax[0].title.set_text('Type')
ax[1].pie(x=df_ps['Content Rating'].value_counts(),labels=df_ps['Content Rating'].value_counts().index,explode=[0,0,0,0,0,1.4],autopct='%1.2f%%')
ax[1].title.set_text('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Type and Content Rating are categorical data and have 2 and 6 unique values, respectively. So a pie chart is an appropriate way to understand them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Most of the apps are free(92%)
#
# 2.   Most app the content rating for everyone(81.8%)
#
# 3.  Very few app has been restricted for 18+ ages and unrated

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For developing a new app, the developer should focus on making the app free and consider the age group of everyone.

# %% [markdown]
# ###4.1.4  **Analysis of  Price Column**

# %% [markdown]
# free type app has 0 price,so  dataframe need to be filterd before analysis

# %%
#staistical describe the price distribution
df_price=df_ps[df_ps['Type']=='Paid']
df_price['Price'].describe()
# Out:
# count    753.000000
# mean      14.096494
# std       58.855019
# min        0.990000
# 25%        1.490000
# 50%        2.990000
# 75%        4.990000
# max      400.000000
# Name: Price, dtype: float64

# %%
#visualise the price distribution

fig,ax=plt.subplots(1,1,figsize=(10,5))
sns.violinplot(x=df_price['Price'],data=df_price,kde=10,color='red')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Price is numerical data, and violinplot is an appropriate approach to visualise the spread of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the apps prices are below 5 dollars. Very few apps have a high price, near $400.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If developers want to launch a new paid app, then the price should be below $5.

# %% [markdown]
# ###4.1.5  **Analysis of  Size Column**

# %% [markdown]
# We can see there are two category of size one is variable size and other is fixed size

# %%
#find the distribution of fixed size and variable size
var_count=len(df_ps[df_ps['Size']=='Varies with device'])
var_per=round((var_count/len(df_ps))*100,2)
fix_per=100-var_per
print(f"In the dataset {var_per} percentage has variable size and {fix_per} percentage has fixed size")
# Out:
# In the dataset 12.72 percentage has variable size and 87.28 percentage has fixed size

# %% [markdown]
# Analysis of size distribution of fixed size apps

# %%
#statistical analysis of size of fix sized app
#filter the fix sized apps
df_fix=df_ps[df_ps['Size']!='Varies with device']
df_1=df_fix.copy()
#convert it into numerical
df_1['Size']=df_1['Size'].apply(lambda x:float(x))
df_1['Size'].describe()
# Out:
# count    8422.000000
# mean       20.413566
# std        21.833476
# min         0.010000
# 25%         4.600000
# 50%        12.000000
# 75%        28.000000
# max       100.000000
# Name: Size, dtype: float64

# %%
#visualistaion of size column
fig,ax=plt.subplots(1,1,figsize=(10,6))
sns.histplot(x=df_1['Size'],data=df_1,kde=True,bins=10,color='green')
# Out:
# <Axes: xlabel='Size', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram plots are ideal for visulalize distribution of numeric data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This is positive skew data. App size lies between 0 and 100MB. Most of them are below 30 MB.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This data does not have enough information about business impact. But the developer should try to keep the app size below 100MB.

# %% [markdown]
# ###4.1.6 **Analysis of  Rating Column**

# %% [markdown]
# To get more clear idea about rating of the dataframe rating column can be convert into categorical data like below

# %%
#create a group rating function
def app_rate(rating):
  '''
  This function helps to categorize the app rating
  '''
  if rating>=4.0:
    return 'Top Rated'
  elif rating>=3.0 and rating<4.0:
    return 'Above Average'
  elif rating>=2.0 and rating<3.0:
    return 'Average'
  else:
    return 'below average'

# %%
#create a column in the dataframe and apply the function in the column
df_ps['Rating Group']=df_ps['Rating'].apply(lambda x:app_rate(x))
df_ps.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      160  19.0     10001  Free    0.0       Everyone
# 1      968  14.0    500001  Free    0.0       Everyone
# 2    87511   8.7   5000001  Free    0.0       Everyone
# 3   215645  25.0  50000001  Free    0.0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
#
#     Rating Group
# 0      Top Rated
# 1  Above Average
# 2      Top Rated
# 3      Top Rated

# %%
#visualize the rating group
fig,ax=plt.subplots(1,2,figsize=(10,5))
sns.histplot(x=df_ps['Rating'],kde=True,bins=30,ax=ax[0])
ax[1].pie(x=df_ps['Rating Group'].value_counts(),labels=df_ps['Rating Group'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# histogram plot is a classical tool for describing numerical data spread and pie chart is appropriate for categorical data with less than 10 unique values

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The majority of the apps have a rating of 4.0 to 5.0, indicating that they are top rated, and they account for 80% of the data.
#
# *   A few apps belong to the average and below average ratings.
#
# *  The median value of the rating is 4.3.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# One of the dependent factors in the popularity of apps is rating, so achieving a top rating is one of the key factors for a successful app. As most of the apps are top-rated,if any app does not belong to the top-rated category, it loses popularity.

# %% [markdown]
# ###4.1.7  Analysis of  Sentiment,Sentiment polarity and Sentiment Subjectivity

# %%
#statistical describe of sentiment_polarity and sentiment_subjectivity
df_ur[['Sentiment_Polarity','Sentiment_Subjectivity']].describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37427.000000            37427.000000
# mean             0.182171                0.492770
# std              0.351318                0.259904
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
#visualisation of sentiment and sentiment polarity and sentiment subjectivity
fig,ax=plt.subplots(3,1,figsize=(20,15))
ax[0].pie(x=df_ur['Sentiment'].value_counts(),labels=df_ur['Sentiment'].value_counts().index,autopct='%1.1f%%')
ax[0].title.set_text('Sentiment Distribution')
sns.histplot(x=df_ur['Sentiment_Polarity'],kde=True,bins=30,ax=ax[1],color='red')
ax[1].title.set_text('Sentiment_Polarity Distribution')
sns.histplot(x=df_ur['Sentiment_Subjectivity'],kde=True,bins=30,color='green',ax=ax[2])
ax[2].title.set_text('Sentiment_Subjectivity Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Sentiment is categorical data, and it has only three unique values, so a pie chart is appropriate. Sentiment polarity and sentiment subjectivity are numerical data, so a histogram is a classical approach to understanding the distribution of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   64.1 percent of the data is positive sentiment, 22.1 percent of the data is negative sentiment, and the rest, 13 percent, is neutral.
# *   Most of the sentiment polarity lies between -0.5 and 0.75.
# *   Most of the sentiment subjectivity is between 0.2 and 0.8.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most of the user has given positive reviews.So if we get any negative reviews we should be concerned about it to stay relevent in the market.

# %% [markdown]
# ##4.2 **Bivariate and Multivariate Analysis**

# %% [markdown]
# Bi means two, and variate means variable, so here there are two variables. The analysis is related to the cause and the relationship between the two variables. There are three types of bivariate analysis.
#
#
# Multivariate analysis is required when more than two variables have to be analysed simultaneously. It is a tremendously hard task for the human brain to visualise a relationship among four variables in a graph, and thus multivariate analysis is used to study more complex sets of data.

# %% [markdown]
# ###4.2.1 **Distribution of install column in each Category**

# %%
#copy the original dataframe
df_ps_1=df_ps.copy()
#add 1 to each row in install column
df_ps_1["Installs"]=df_ps_1["Installs"].apply(lambda x:x+1)
#make the install column to logarithimic
df_ps_1["Installs"]=df_ps_1["Installs"].apply(lambda x:np.log10(x))
#visualize the data
g = sns.FacetGrid(df_ps_1, col='Category', palette="Set1",  col_wrap=5, height=4)
g = (g.map(plt.hist,"Installs", bins=10, color='g'))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# FacetGrid helps visualise the distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels. So for an analysis of installs for each category, facetgrid is ideal for that.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   All categories have widely spread installed data, whether they have a large number of apps or a small number of apps.
#
# *  Lower and higher numbers of installs are less frequent, and midsize numbers of installs are most frequent in tools,photography,personalization, games,productivity, communication, and personalization.
#
#
# *   Arts and Design,Beauty,Comics,Education,Entertainment,House and Home,Libraries and Demo, Parenting, and Weather categories have a lower number of installations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the app category is Game or Family, it has a high possibility of getting a high number of installations, or if the category belongs to Parenting, Weather,Maps and navigation, it has a good possibility of getting a low number of installations.

# %% [markdown]
# ###4.2.2 **Size vs Rating for each Category**

# %% [markdown]
# before visualisation app data should divided in two category variable size and fixed size..

# %%
#eliminate the variable size
df_ps_size=df_ps[df_ps['Size']!='Varies with device']
#visualize the plot of fixed sized apps
g = sns.FacetGrid(df_ps_size, col='Category',hue='Type', palette="Set1",  col_wrap=5, height=4)
g = (g.map(plt.scatter,"Size","Rating",).add_legend())

# %%
#Visualization of installation of app of Variable Sized App
df_ps_var=df_ps[df_ps['Size']=='Varies with device']
fig,ax=plt.subplots(1,1,figsize=(15,35))
sns.barplot(data=df_ps_var,y=df_ps_var.Category,x=df_ps_var['Rating'],hue=df_ps_var['Type']);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# FacetGrid can be drawn with up to three dimensions: row, col, and hue. The first two have obvious correspondence with the resulting array of axes; think of the hue variable as a third dimension along a depth axis, where different levels are plotted with different colours. So for size vs. rating in each category, a facet grid is appropriate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Large size apps always get high ratings, but small size apps get mixed ratings for most of the categories except medical,lifestyle, tools, and family, which have mixed ratings all through size.
#
# * Paid apps are generally better rated than free apps.
#
# * For the variable size of the app rating, most apps are highly rated except for parenting. Paid parenting apps are low-rated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Rating does not have much dependency on app size.

# %% [markdown]
# ###4.2.3 **Installation and Android Version Relation**

# %%
#create a function to grouped the android column
def min_andr(version):
  '''
  This function helps to categorize the android version in few unique number
  '''
  if version=='Varies with device':
    return version
  else:
    min_ver=version[0]
  return min_ver

# %%
#apply the function to anderoid column
df_ps['Minimum Android Version']=df_ps['Android Ver'].apply(lambda x:min_andr(x))
#create groupby data with minimum android version and Total installs
and_ins=df_ps.groupby(['Minimum Android Version'])['Installs'].sum()
#visualize the plot
fig,ax=plt.subplots(1,1,figsize=(10,8))
sns.barplot(x=and_ins.index,y=and_ins)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are mainly used for count visualisation. So for plotting, installing count among Android versions is appropriate with Barchart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Users prefer the Android version of the app, which varies with device; besides, Android 4 is also highly popular.
#
# *   Other Android versions are not so preferred by users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While developing a new app, the app's Android version is one of its main features. For the success of the app, the developer should go with a variable device or Android 4, and other versions should be avoided.

# %% [markdown]
# ###4.2.4 **Installs vs App size**

# %% [markdown]
# For better analysis, we have to create an app-sized group.

# %%
#create app_size group
def app_size_group(size):
  '''
  This function is create group of appsize between 0-100MB
  '''
  try:
    if size<1.0:
      return 'Below 1MB'
    elif size>=1.0 and size<5.0:
      return 'Below 5MB'
    elif size>=5.0 and size>15.0:
      return '5-15MB'
    elif size>=15.0 and size<30.0:
      return '15-30MB'
    elif size>=30.0 and size<60.0:
      return '30-60MB'
    elif size>=60.0 and size<100.0:
      return '60-100MB'
    else:
      return 'Above 100MB'
  except:
    return size

# %%
#apply the function to the dataframe
df_ps['appsize_category']=df_ps['Size'].apply(lambda x:app_size_group(x))
df_ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      160  19.0     10001  Free    0.0       Everyone
# 1      968  14.0    500001  Free    0.0       Everyone
# 2    87511   8.7   5000001  Free    0.0       Everyone
# 3   215645  25.0  50000001  Free    0.0           Teen
# 4      968   2.8    100001  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#     Rating Group Minimum Android Version appsize_category
# 0      Top Rated                       4           5-15MB
# 1  Above Average                       4      Above 100MB
# 2      Top Rated                       4      Above 100MB
# 3      Top Rated                       4           5-15MB
# 4      Top Rated                       4        Below 5MB

# %%
#groupby the appsize_category and type with install
appsize_cat_ins= df_ps.groupby(['appsize_category','Type'])['Installs'].sum().unstack()
appsize_cat_ins
# Out:
# Type                       Free      Paid
# appsize_category
# 15-30MB               464247073    335611
# 5-15MB              22796502983  32387096
# Above 100MB          6375614052   6120285
# Below 1MB             116683814   1866799
# Below 5MB            1605661703   1569400
# Varies with device  43705345817  15035433

# %%
#visualization code most installed app size
fig,ax=plt.subplots(1,2,figsize=(20,6))
sns.barplot(data=df_ps[df_ps['Type']=='Free'],x='appsize_category',y='Installs',hue='Rating Group',ax=ax[0],palette='icefire');
ax[0].set_title('Size vs installs in Free App')
sns.barplot(data=df_ps[df_ps['Type']=='Paid'],x='appsize_category',y='Installs',hue='Rating Group',ax=ax[1],palette='gnuplot');
ax[1].set_title('Size vs installs in Paid App')
# Out:
# Text(0.5, 1.0, 'Size vs installs in Paid App')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The size column is a mix of categorical and numerical data. So for better understanding, it is converted into categorical data. Bar chart is appropriate for categorical and numerical visualisation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Whether the app is free or paid depends on which device has the highest number of installations.
#
# * For free apps, app sizes between 5 MB and 30 MB have high installation. For paid apps, 5–15 app sizes have decent installation.
#
# *For free apps that are near about 100 MB, they has poorly rated, but paid apps that are near about 100 MB are highly rated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For designing the new app, the app size should be variable with the device. For fixed-size apps, the preferred app size is 5–30 MB for free and 5–15 MB for paid apps. But for large apps, it is preferred to be paid for a high rating.

# %% [markdown]
# ###4.2.5 **Sentiment Polarity vs Sentiment Subjectivity**

# %%
#plot the sentiment poarity vs sentiment subjectivity

g = sns.JointGrid(data=df_ur, y='Sentiment_Polarity', x='Sentiment_Subjectivity',hue='Sentiment')
g.plot(sns.scatterplot, sns.kdeplot);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Joint plots allow plotting a relationship between two variables (also known as a bivariate relationship) while simultaneously exploring the distribution of each underlying variable. So,to understand sentiment subjectivity and sentiment polarity relations, a joint plot is ideal.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Lower sentiment subjectivity means lower sentiment polarity, and higher sentiment subjectivity has widely spread polarity.
#
# *   Neutral sentiment is independent of subjectivity.
#
# *   Negative sentiment polarity has a lower frequency than positive sentiment polarity.
#
# * Most of the sentiment polarity lies between -0.5 and 0.75.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Translated reviews with lower sentiment and subjectivity are useless for understanding the popularity of the app.

# %% [markdown]
# ###4.2.6 **Does Sentiment Polarity has affect on Rating?**

# %%
#create a column in the dataframe and apply the function in the column
merged_df['Rating Group']=merged_df['Rating'].apply(lambda x:app_rate(x))
#visualize the sentiment polarity distribution in each rating group
sns.catplot(x='Rating Group', y='Mean_Sentiment_Polarity',
            data=merged_df,
            kind='box');

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Catplot is ideal for categorical and numerical data visualisation. So for sentiment subjectivity and rating group analysis, a catplot is ideal.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The top-rated group has the maximum positive sentiment polarity. Only a few outliers have negative sentiment polarity.
#
# *   The average-rated group has a negative majority of the sentiment polarity.
# *   The above-average-rated group has few negative sentiments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive sentiment polarity has a tendency towards above-average and top-rated groups, and a high rating can give a high installation, and vice versa.

# %% [markdown]
# ###**4.2.7 Sentiment Subjectivity distribution of each Rating group**

# %%
# visualize the sentiment subjectivity distribution  of each rating group
sns.catplot(x='Rating Group', y='Mean_Sentiment_Subjectivity',
            data=merged_df,
            kind='box');

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Most of the Sentiment Subjectivity of the top rated app  and above average app lies between 0.3 to 0.7.Outliers also present in higher and lower magnitude of subjectivity
#
# *   Most of the sentiment  subjectivity of the top-rated and above-average apps lies between 0.3 and 0.7. Outliers are also present at higher and lower magnitudes of subjectivity.

# %% [markdown]
# ###4.2.8 **Pairplot of playstore data**

# %%
#visuaise the pairplot data
df_ps_nz=df_ps.copy()
df_ps_nz['Installs']=df_ps_nz['Installs'].apply(lambda x:x+1)
df_ps_nz['Reviews']=df_ps_nz['Reviews'].apply(lambda x:x+1)
Rating = df_ps_nz['Rating']
Size = df_ps_nz['Size']
Installs = df_ps_nz['Installs']
Reviews = df_ps_nz['Reviews']
Type = df_ps_nz['Type']
Price = df_ps_nz['Price']
plt.figure(figsize=(10,10))
pair = sns.pairplot(pd.DataFrame(list(zip(Rating, Size, np.log10(Installs), np.log10(Reviews), Price, Type)),
                        columns=['Rating','Size', 'Installs', 'Reviews', 'Price','Type']), hue='Type')
#pair.fig.suptitle("Pairwise Plot - Rating, Size, Installs, Reviews, Price",x=0.5, y=1.0, fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is a data visualisation that plots pair-wise relationships between all the variables in a dataset. This helps to better understand the relationships visually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   A higher number of reviews gets a higher rating,but a highly rated app may or may not get a high number of reviews.
#
# *   A higher number of installations gets a high rating, but a highly rated app may or may not get a high number of installations.
#
# *   The price column has a very low dependency on ratings, reviews, and installs
#
# *  Review and Installation have a linear relationship.
#
# *   Paid apps do not have high numbers of reviews,and free apps have a high spread of reviews.
#
# *   Paid apps do not have a large number of installations compared to free apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To get a high number of installations, apps must be free, or they have to find an optimum price because a high price reduces the number of installations.
#
#
# A higher number of reviews is also desirable for large installations, which means more reviews can increase the popularity of the product, and the same goes with ratings.
#
#
# If the app is paid, then it should belong in the top rating group.

# %% [markdown]
# ###4.2.9. **Co_relation of playstore data**

# %%
#co_relation heatmap of playstore data
plt.figure(figsize = (10,8))
sns.heatmap(df_ps.corr(), annot= True)
plt.title(' Heatmap for Playstore Dataframe', size=10)
# Out:
# Text(0.5, 1.0, ' Heatmap for Playstore Dataframe')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation analysis measures the statistical relationship between two different variables. The result will show how the change in one parameter would impact the other parameter. Correlation analysis is a very important concept popular in the field of predictive analytics.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Installs and reviews are highly positive co-related, meaning they both increase at the same time.
#
# *  Rest of the columns has low co-relation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We should focus on getting a high number of reviews, then we will get a high number of installations,or we have to inspire the users to provide the reviews as many times as they can.

# %% [markdown]
# ###4.2.10 **Corelation of merged dataframe**

# %%
#co_relation heatmap of merged data
plt.figure(figsize = (10,6))
sns.heatmap(merged_df.corr(), annot= True,cmap="icefire")
plt.title(' Heatmap for merged Dataframe', size=10)
# Out:
# Text(0.5, 1.0, ' Heatmap for merged Dataframe')

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# *    Besides installing and reviewing sentiment polarity, positive sentiment and negative sentiment have a high correlation.
#
#
#
#
# *   Positive sentiment with neutral sentiment has medium strength of co-relation.
#
# * Mean sentiment subjectivity has medium correlation strength with rating, and mean sentiment subjectivity
#
# * Review has high correlation strength with positive sentiment.
#
# * Mean sentiment polarity and negative sentiment have negative co-relation strength.

# %% [markdown]
# ### 4.3. **Asking and Answsering Questions**

# %% [markdown]
# 1) **Tools and Medical apps, is the average rating signifcantly different in each category?**

# %%
#list out the rating data of two category
tools = list(df_ps[df_ps.Category == "TOOLS"].Rating)
medical = list(df_ps[df_ps.Category == "MEDICAL"].Rating)
#check if the plots are normal
sns.kdeplot(tools)
sns.kdeplot(medical)
plt.title("Rating distributions")
# Out:
# Text(0.5, 1.0, 'Rating distributions')

# %%
#make numpy array of the data
tools_array = np.asarray(tools)
medical_array = np.asarray(medical)
#calculate the standard deviation
print("Standard deviation of tools app ratings:", tools_array.std())
print("Standard deviation of medical app ratings:", medical_array.std())
# Out:
# Standard deviation of tools app ratings: 0.5848684436851871
# Standard deviation of medical app ratings: 0.5939747677094818

# %%
#import statistics library to run the hypothesis test
from scipy.stats import ttest_ind
#confidence interval: 95%
#setting confidence interval sets our alpha (treshold value) = 1-0.95 = 0.05

#Null Hypothesis: Difference in the mean rating of Tools and Medical apps are due to a random chance
#Alternative Hypothesis: Mean rating of Tools and Medical apps are significantly different

#p-value = when it is assumed that our null hypothesis is correct, p value gives us the probability of
#getting a sample with the results we assumed.

#run the 2 sample test:

_, pvalue = ttest_ind(tools, medical)
if pvalue<=0.05:
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
# Out:
# Reject Null Hypothesis

# %% [markdown]
# #### 1)**Which category have most number of app and least number of app?**

# %%
#find out top 3 category
fig,ax=plt.subplots(1,2,figsize=(12,6))
top=df_ps['Category'].value_counts().head(3)
sns.barplot(x=top.index,y=top,ax=ax[0])
ax[0].set_title('Top 3 Category')
#find out least 3 category
low=df_ps['Category'].value_counts().tail(3)
sns.barplot(x=low.index,y=low,ax=ax[1])
ax[1].set_title('Least 3 Category')
# Out:
# Text(0.5, 1.0, 'Least 3 Category')

# %% [markdown]
# The family category of the app has the highest presence, and it has 1829 apps. Other top categories include games and tools, which have 959 and 825 apps, respectively. The beauty category has the fewest apps, with only 53. Other less popular categories include comics and parenting, which have 56 and 60 apps, respectively.

# %% [markdown]
# ###2)**Which category has maximum number and minimum number of installation?**

# %%
cg_ins_max= df_ps.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).head(3)
cg_ins_min= df_ps.groupby(['Category'])['Installs'].sum().sort_values().head(3)
fig, ax = plt.subplots(1,2,figsize=(10,5))
sns.barplot(y=cg_ins_max,x=cg_ins_max.index,data=df_ps,ax=ax[0])
ax[0].set_title('Maximum installed Category')
sns.barplot(y=cg_ins_min,x=cg_ins_min.index,data=df_ps,ax=ax[1])
ax[1].set_title('Minimum Installed Category')
plt.show()

# %% [markdown]
# Games, communication, and tools have the maximum number of installations. Events, Beauty, and Parenting have a minimum number of installations.

# %% [markdown]
# ###3)**Find out the most popular app**

# %% [markdown]
# To find out the most popular app,we have to first
#
#
# 1. Most number of installed apps
#
#
# 2. Among the most installed apps, find which app has the most reviews.
#
#
# 3. If there is a tie, then find which app has the highest rating.

# %%
# find out the maximum installed app
max_app=df_ps[df_ps['Installs']==df_ps.Installs.max()]
#plot the maximum installed apps
fig,ax=plt.subplots(figsize=(20,8))
top_visual=sns.barplot(x=max_app.App,y=max_app.Installs)
#rotate the xticklabels
top_visual.set_xticklabels(top_visual.get_xticklabels(), rotation= 75, horizontalalignment='right')
plt.show()

# %%
#find out app has the maximum reviews which have maximum no of installation
fig,ax=plt.subplots(1,1,figsize=(12,8))
max_review=sns.barplot(x=max_app.App,y=max_app.Reviews)
max_review.set_xticklabels(top_visual.get_xticklabels(), rotation= 75, horizontalalignment='right')
plt.show()

# %% [markdown]
# **Facebook is the most popular app in the Play Store, and after Facebook, WhatsApp is the most popular app in the Play Store.**

# %% [markdown]
# From the univariate analysis section, we have seen that 92% of the apps in the dataset are free and 8% are paid.

# %% [markdown]
# ### **4)Which category has most no of paid apps?**

# %%
# from a groupby by type category
type_cat=df_ps.groupby('Category')['Type'].value_counts().unstack()
#fill the null values with zero
type_cat.fillna(0,inplace=True)
#sort the category in order of paid app
paid_cat=type_cat.sort_values(by='Paid',ascending=False).head(3)
paid_cat
# Out:
# Type        Free   Paid
# Category
# FAMILY    1647.0  182.0
# MEDICAL    312.0   83.0
# GAME       877.0   82.0

# %%
#visualise the plot
paid_cat.plot(kind="bar",figsize=(8, 5))
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# Family, Medical, and Game categories have the most paid apps, and the numbers are 182, 83, and 82.

# %% [markdown]
# ###**5)Find the top 5 paid app according to revenue.**

# %%
#separate the paid app from dataframe
df_paid=df_ps[df_ps['Type']=='Paid']
df_pay=df_paid.copy()
#create a new column of reveneau
df_pay['Reveneau']=df_pay['Installs']*df_pay['Price']
#sort the dataframe by reveneu
apps_=df_pay.sort_values(by='Reveneau',ascending=False).head()
#visualise the data
fig,ax=plt.subplots(figsize=(12,6))
sns.barplot(x=apps_.App,y=apps_.Reveneau)
ax.set_title('Top Reveneau app')
# Out:
# Text(0.5, 1.0, 'Top Reveneau app')

# %% [markdown]
# The top 5 earned apps are Minecraft,I am Rich,I am Rich Premium, Hitman Sniper, and Grand Theft Auto:San Andreas.

# %% [markdown]
# ###**6)What are the top  large size apps?also find out most popular app among them.**

# %%
#find out the largest apps
max_size=df_1[df_1['Size']==df_1['Size'].max()]
max_size.sort_values(by=['Installs','Reviews','Rating'],ascending=False).head()
# Out:
#                                  App   Category  Rating  Reviews   Size  \
# 1758          Hungry Shark Evolution       GAME     4.5  6074335  100.0
# 7404                 SimCity BuildIt     FAMILY     4.5  4218588  100.0
# 5862           Miami crime simulator       GAME     4.0   254519  100.0
# 5427                 Ultimate Tennis     SPORTS     4.3   183005  100.0
# 1565  Talking Babsy Baby: Baby Games  LIFESTYLE     4.0   140996  100.0
#
#        Installs  Type  Price Content Rating                  Genres  \
# 1758  100000001  Free    0.0           Teen                  Arcade
# 7404   50000001  Free    0.0   Everyone 10+              Simulation
# 5862   10000001  Free    0.0     Mature 17+                  Action
# 5427   10000001  Free    0.0       Everyone                  Sports
# 1565   10000001  Free    0.0       Everyone  Lifestyle;Pretend Play
#
#      Last Updated   Current Ver   Android Ver
# 1758   2018-07-25         6.0.0    4.1 and up
# 7404   2018-06-19  1.23.3.75024    4.0 and up
# 5862   2018-07-09           2.0    4.0 and up
# 5427   2018-07-19     2.29.3118  4.0.3 and up
# 1565   2018-07-16           9.0    4.0 and up

# %% [markdown]
# Hungry Shark Evolution is the most popular large-size app; after that, Simcity Buildit and Miami Crime Simulator are the most popular apps in the dataset.

# %% [markdown]
# ####**7)What are the top genres of apps with the most installations?**

# %%
genre_app=df_ps.groupby(['Genres'])['Installs'].sum().sort_values(ascending=False).head()
plt.subplots(figsize=(10,5))
sns.barplot(x=genre_app,y=genre_app.index)
plt.ylabel('Genre')
plt.xlabel('No of Installs')
plt.title('barchart of top 5 genres belongs to apps');

# %% [markdown]
# Communication,Tools,Productivity genre has most number of installation.

# %% [markdown]
# ###**8)Are there any apps which have not been updated since years ?**

# %% [markdown]
# For this, we are going to add two more columns, named Year and Month.

# %%
#For this we are going to add two more columns named Year and Month
d = pd.DatetimeIndex(df_ps['Last Updated'])
df_ps['year'] = d.year
df_ps['month'] = d.month
df_ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      160  19.0     10001  Free    0.0       Everyone
# 1      968  14.0    500001  Free    0.0       Everyone
# 2    87511   8.7   5000001  Free    0.0       Everyone
# 3   215645  25.0  50000001  Free    0.0           Teen
# 4      968   2.8    100001  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#     Rating Group Minimum Android Version appsize_category  year  month
# 0      Top Rated                       4           5-15MB  2018      1
# 1  Above Average                       4      Above 100MB  2018      1
# 2      Top Rated                       4      Above 100MB  2018      8
# 3      Top Rated                       4           5-15MB  2018      6
# 4      Top Rated                       4        Below 5MB  2018      6

# %%
print('Number of apps that has not been updated since 2017 are {}'.format(len(df_ps[df_ps['year'] < 2017])))
print('Number of apps that has not been updated since 2016 are {}'.format(len(df_ps[df_ps['year'] < 2016])))
print('Number of apps that has not been updated since 2015 {}'.format(len(df_ps[df_ps['year'] < 2015])))
print('Number of apps that has not been updated since 2014 {}'.format(len(df_ps[df_ps['year'] < 2014])))
# Out:
# Number of apps that has not been updated since 2017 are 1578
# Number of apps that has not been updated since 2016 are 801
# Number of apps that has not been updated since 2015 352
# Number of apps that has not been updated since 2014 149

# %% [markdown]
# Around 3,000 apps have not been updated in years. Maybe these apps have not been in the service.

# %% [markdown]
# ### **9)Find out the most positive reviews and most negative reviews.Also find out their installation and rating.**

# %%
r_p=merged_df.sort_values(by='Positive_Sentiment',ascending=False).head()
r_p
# Out:
#                                 App            Category  Rating  Reviews  \
# 322                      Helix Jump                GAME     4.2  1497361
# 125  Duolingo: Learn Languages Free           EDUCATION     4.7  6289924
# 263        Calorie Counter - Macros  HEALTH_AND_FITNESS     4.0     3061
# 243  Calorie Counter - MyFitnessPal  HEALTH_AND_FITNESS     4.6  1873516
# 344                      Bowmasters                GAME     4.7  1534466
#
#                    Size   Installs  Type  Price Content Rating  \
# 322                33.0  100000000  Free    0.0       Everyone
# 125  Varies with device  100000000  Free    0.0       Everyone
# 263                 5.5     100000  Free    0.0       Everyone
# 243  Varies with device   50000000  Free    0.0       Everyone
# 344  Varies with device   50000000  Free    0.0           Teen
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# 322               Action   2018-04-09               1.0.6          4.1 and up
# 125  Education;Education   2018-08-01  Varies with device  Varies with device
# 263     Health & Fitness   2016-08-27               2.3.4          5.0 and up
# 243     Health & Fitness   2018-07-31  Varies with device  Varies with device
# 344               Action   2018-07-23              2.12.5          4.1 and up
#
#      Negative_Sentiment  Neutral_Sentiment  Positive_Sentiment  \
# 322                58.0                6.0               209.0
# 125                34.0                6.0               200.0
# 263                20.0                6.0               174.0
# 243                52.0               33.0               169.0
# 344               119.0               24.0               169.0
#
#      Mean_Sentiment_Polarity  Mean_Sentiment_Subjectivity Rating Group
# 322                 0.099665                     0.487221    Top Rated
# 125                 0.200408                     0.470215    Top Rated
# 263                 0.247519                     0.512675    Top Rated
# 243                 0.216523                     0.474814    Top Rated
# 344                 0.061415                     0.500548    Top Rated

# %% [markdown]
# Helix Jump is the most positively reviewed app in the Play Store.

# %%
r_j=merged_df.sort_values(by='Negative_Sentiment',ascending=False).head()
r_j_new=r_j.reset_index()
r_j_new
# Out:
#    index                    App Category  Rating   Reviews  \
# 0    331    Angry Birds Classic     GAME     4.4   5566669
# 1    318       Candy Crush Saga     GAME     4.4  22426677
# 2    344             Bowmasters     GAME     4.7   1534466
# 3    328            8 Ball Pool     GAME     4.5  14198297
# 4    325  Candy Crush Soda Saga     GAME     4.4   6198563
#
#                  Size   Installs  Type  Price Content Rating  Genres  \
# 0                97.0  100000000  Free    0.0       Everyone  Arcade
# 1                74.0  500000000  Free    0.0       Everyone  Casual
# 2  Varies with device   50000000  Free    0.0           Teen  Action
# 3                52.0  100000000  Free    0.0       Everyone  Sports
# 4                67.0  100000000  Free    0.0       Everyone  Casual
#
#   Last Updated Current Ver   Android Ver  Negative_Sentiment  \
# 0   2018-05-24       7.9.3    4.1 and up               147.0
# 1   2018-07-05   1.129.0.2    4.1 and up               126.0
# 2   2018-07-23      2.12.5    4.1 and up               119.0
# 3   2018-07-31       4.0.0  4.0.3 and up               106.0
# 4   2018-07-10     1.118.4    4.1 and up                96.0
#
#    Neutral_Sentiment  Positive_Sentiment  Mean_Sentiment_Polarity  \
# 0                2.0               124.0                -0.007537
# 1               12.0               102.0                 0.031068
# 2               24.0               169.0                 0.061415
# 3                9.0               104.0                 0.001252
# 4                8.0                62.0                -0.057079
#
#    Mean_Sentiment_Subjectivity Rating Group
# 0                     0.534886    Top Rated
# 1                     0.456293    Top Rated
# 2                     0.500548    Top Rated
# 3                     0.491352    Top Rated
# 4                     0.481330    Top Rated

# %% [markdown]
# Angry Bird Classic is the most negatively reviewed app in the Play Store.

# %% [markdown]
# ###**10). How  sentiment polarity affect in Rating?**

# %%
#plot the sentiment polarity
fig,ax=plt.subplots(1,1,figsize=(8,8))
sns.scatterplot(data=merged_df,y=merged_df['Positive_Sentiment'],x=merged_df['Negative_Sentiment'],hue=merged_df['Rating Group']);

# %% [markdown]
# When positive sentiment and negative sentiment are both low,, the rating is mixed (it may be high or low), but when both are high, the rating is high. When positive sentiment is high and negative sentiment is low, the rating is also high.

# %% [markdown]
# ###**11)Find Top 20 Costly App**

# %%
#find the paid app sorted by price
paid_app=df_ps[df_ps['Type']=='Paid'].sort_values(by='Price',ascending=False).head(10)

#visualize the apps
fig,ax=plt.subplots(figsize=(15,8))
app_type_visuals=sns.barplot(data=paid_app,x=paid_app['App'],y=paid_app['Installs']);
app_type_visuals.set_xticklabels(app_type_visuals.get_xticklabels(),rotation=75);
plt.show()

# %% [markdown]
# The top 10 paid apps are I'm Rich: Trump Edition,I Am Rich Premium,I Am Rich Pro Plus, I am Rich, I am Rich (Most Expensive App), I Am Rich Pro, Most Expensive App (H), I am Rich (Premium), I am Rich!.

# %% [markdown]
# ####**12) Find the top 10 games**

# %%
# Chart - 9 visualization code
def cat_top10(category):
  '''
  Plot  top 10 installed app of given category
  '''
  df_top=df_ps[df_ps['Category']==category]
  data=df_top[['App','Installs']].sort_values('Installs',ascending=False).head(10)
  fig,ax=plt.subplots(figsize=(15,5))
  #ax.set_title('Top 10 installed App ')
  visuals=sns.barplot(x=data.App,y=data.Installs,palette='husl')
  visuals.set_xticklabels(visuals.get_xticklabels(), rotation= 75, horizontalalignment='right')

# %%
cat_top10('GAME')

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * Most of the apps are free (92%). So the developer should focus on making the app free to achieve a high customer base. But if the app is paid, then try to set the price below $50.
#
# * The categories of apps should be like events, beauty, and parenting because these categories are less explored. The number of apps is less, but installation is pretty high.
#
# * App size should be variable with the device as it has a high installation of apps that belong to this size. If the app size is fixed, then try to keep the size between 5 and 15 MB. If the category is game or family, the size can be large.In brief, app size does has large impact on installation.
#
# * The preferred content rating for everyone and the preferred genre should be communications,tools, photography, and social.
#
# * Android version is preferred to be variable with the device or Android 4.
#
# * If the category is games, the developer should be cautious because it has the most negative reviews.
#
# * The app should be updated over time with respect to user preferences and overcome the issues mentioned in reviews.
#
# * The target audience of the app should be top-rated, which means above 4.0, and installation should be around 10 lakh.
#
# * These are some aspects that developers should research before developing an app. Besides avoiding the risk of failure, EDA provides better ideas about how to design the app.
#
#
# *   The app should be updated over time with respect to user preferences and overcome the issues mentioned in reviews.
#
#
# * The target audience of the app should be top-rated, which means above 4.0, and installation should be around 10 lakh.
#
#
# * These are some aspects that developers should research before developing an app. Besides avoiding the risk of failure, EDA provides better ideas about how to design the app.
#
#
#
# * The target audience of the app should be top-rated, which means above 4.0, and installation should be around 10 lakh.
#
# * These are some aspects that developers should research before developing an app. Besides avoiding the risk of failure, EDA provides better ideas about how to design the app.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Facebook is the most popular app in the Play Store.
#
# * Helix Jumps is the most positively reviewed app, and angry birds classic is the most negatively reviewed app.
#
# * When an app has high positive and negative reviews, the rating gets high, which means that when it has been updated, it has overcome the negative subjectivity.
#
# * I am rich. Premium is one of the paid apps with the highest number of installations.
#
# * Around 3000 apps have not been updated in the last few years, implying that a large number of them are no longer in service.
#
# * Paid apps are generally higher rated than free apps in each category except the parenting category.
#
# * When the app size is very high, there are few numbers, but the installation number is high.
#
# * The major challenge of this project was the data cleaning part. Around 15 percent of the data was missing from the Play Store, and around 42 percent of the data was missing from user reviews.
#
# * Only 816 apps have a common link between user reviews and Play Store data. It is around 10 percent of the Play Store app number. So the data is sufficient for the analysis of merged data.
#
# * Current version, Last Update, and Sentiment Subjectivity should be analysed for effect in rating and installation.
#
# * The data journey of the app (installation, rating, and review) over the year should have helped to understand businesses more effectively.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
